# %%
import os
import exp_util as eu
import exp_func as ef
from exp_util import *
from exp_func import *
from importlib import reload
# %load_ext autoreload
# %autoreload 2
os.makedirs(eu._latex_dir, exist_ok=True)

# %%
from exp_util import *
from exp_func import *
eu = reload(eu)
ef = reload(ef)

arg_default_map_dict = eu.arg_default_map_dict.copy()
delta = 3
dataNames = ["wiki2", "imdb2", "dblp", "egr1"]
# dataNames = ["dblp"] # uncomment this line to test DBLP only
get_table_accuracy_of_estimators_in_default_setting(delta=delta, dataNames=dataNames)
# Out:
#                      WIKI                               IMDB              \
#                      Avg.  50th  90th   99th      Max.  Avg.  50th  90th
# Traditional LBS      3.75  1.50  7.00  35.00   1418.00  3.17  1.35  6.15
# Base        CardNet  4.27  1.66  5.63  35.29  25898.60  2.59  1.54  4.48
#             DREAM    3.29  1.63  4.63  23.99   9752.90  2.25  1.46  3.79
# Prefix      Astrid   6.91  1.83  7.47  47.42  23618.82  3.56  1.51  4.01
#             CardNet  3.36  1.60  4.87  26.21   1914.18  2.18  1.39  3.60
#             DREAM    2.66  1.50  4.11  18.40   1278.81  2.01  1.39  3.28
#
#                                        DBLP                             GENE  \
#                       99th       Max.  Avg.  50th  90th   99th    Max.  Avg.
# Traditional LBS      25.71     528.03  3.00  1.32  6.00  26.00  178.22  2.88
# Base        CardNet  15.84    1454.43  3.30  1.67  6.00  24.79  232.52  1.63
#             DREAM    12.47    1248.44  2.87  1.51  4.79  21.15  291.28  1.23
# Prefix      Astrid   16.55  159886.55  3.13  1.53  5.88  25.89  204.01  1.45
#             CardNet  12.70    2040.32  2.81  1.43  5.01  20.33  414.15  1.53
#             DREAM    10.33     598.38  2.03  1.25  3.27  12.61  151.84  1.20
#
#
#                      50th  90th   99th   Max.
# Traditional LBS      1.31  6.49  23.14  60.96
# Base        CardNet  1.22  2.61   6.54  41.34
#             DREAM    1.05  1.68   3.07  18.74
# Prefix      Astrid   1.12  2.07   4.95  65.78
#             CardNet  1.15  2.30   6.18  42.30
#             DREAM    1.05  1.56   2.93  16.86

# %%
from exp_util import *
from exp_func import *
eu = reload(eu)
ef = reload(ef)

timeout = 30 * 3600
delta = 3
dataNames = ["wiki2", "imdb2", "dblp", "egr1"]
# dataNames = ["dblp"] # uncomment this line to test DBLP only
exp1_qs_vs_gt(prefix=False, delta=delta, timeout=timeout, dataNames=dataNames)
exp1_qs_vs_gt(prefix=True, delta=delta, timeout=timeout, dataNames=dataNames)
# Out:
# fig saved at: figures/qry_size_vs_time_wiki2_3.png
# fig saved at: figures/qry_size_vs_time_imdb2_3.png
# fig saved at: figures/qry_size_vs_time_dblp_3.png
# fig saved at: figures/qry_size_vs_time_egr1_3.png
# fig saved at: figures/qry_size_vs_time_wiki2_3_prfx.png
# fig saved at: figures/qry_size_vs_time_imdb2_3_prfx.png
# fig saved at: figures/qry_size_vs_time_dblp_3_prfx.png
# fig saved at: figures/qry_size_vs_time_egr1_3_prfx.png
