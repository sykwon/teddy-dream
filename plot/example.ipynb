# %%
import os
import exp_util as eu
import exp_func as ef
from exp_util import *
from exp_func import *
from importlib import reload
# %load_ext autoreload
# %autoreload 2
os.makedirs(eu._latex_dir, exist_ok=True)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from exp_util import *
from exp_func import *
eu = reload(eu)
ef = reload(ef)

arg_default_map_dict = eu.arg_default_map_dict.copy()
delta = 3
dataNames = ["DBLP"] 
# dataNames = ["WIKI", "IMDB", "DBLP", "GENE"] # uncomment this line for all datasets 
get_table_accuracy_of_estimators_in_default_setting(delta=delta, dataNames=dataNames, verbose_level=1)
# Out:
#                      DBLP
#                      Avg.  50th  90th   99th    Max.
# Traditional LBS      3.01  1.32  6.00  26.00  178.22
# Base        CardNet  3.30  1.67  6.00  24.79  232.52
#             DREAM    2.87  1.51  4.79  21.15  291.28
# Prefix      Astrid   3.13  1.53  5.80  25.89  204.01
#             CardNet  2.81  1.43  5.01  20.33  414.15
#             DREAM    2.03  1.25  3.27  12.61  151.84

# %%
from exp_util import *
from exp_func import *
eu = reload(eu)
ef = reload(ef)

timeout = 30 * 3600
delta = 3
dataNames = ["DBLP"] 
# dataNames = ["WIKI", "IMDB", "DBLP", "GENE"] # uncomment this line for all datasets 
exp1_qs_vs_gt(prefix=False, delta=delta, timeout=timeout, dataNames=dataNames)
exp1_qs_vs_gt(prefix=True, delta=delta, timeout=timeout, dataNames=dataNames)
# Out:
# fig saved at: figures/qry_size_vs_time_DBLP_3.png
# fig saved at: figures/qry_size_vs_time_DBLP_3_prfx.png
